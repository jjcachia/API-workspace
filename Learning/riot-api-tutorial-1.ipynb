# %% [markdown]
# ## **Riot API Tutorial (2025-02-25)**
#
# *This sandbox follows the youtube tutorial series by Beora ([Youtube Link](https://www.youtube.com/watch?v=A5c0yfEiYjQ&list=PLnnM9dgSdUvIe0MRJcjbzBaJWFHNJaOh1)). It is meant to give a basic Introduction to the Tools Necessary to Get Started working on Projects utilising Riot's API.*

# %% [markdown]
# ### **1. Establishing Credentials**

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.environ.get('riot_api_key'))
# Out:
# RGAPI-e6166e33-d300-4f07-a8b9-4d47f978a885

# %%
import pygsheets

service_account = pygsheets.authorize(service_account_file='JSONs\\spreadsheet-automator-452009-1b2fd6310821.json')

sheet = service_account.open_by_url('https://docs.google.com/spreadsheets/d/1F38cGIAQtiPwX0CjVb742iqwnnMW8Lh2Exy-SRP_BrM/edit?usp=sharing')

# %%
test = sheet.worksheet_by_title('Test')

# %%
test_df = test.get_as_df()

# %%
test_df['random_numbers'] = 1

# %%
test.set_dataframe(test_df, 'A1', copy_head=True)

# %% [markdown]
# ### **2. Interacting with the API**

# %%
from dotenv import load_dotenv
load_dotenv()

import os
import requests

gameName = 'LordVoItage'
tagLine = 'EUW'
api_key = os.environ.get('riot_api_key')

def get_puuid(gameName=None, tagLine=None, api_key=None):
    link = f'https://europe.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}%20/{tagLine}?api_key={api_key}'

    response = requests.get(link)
    response.json()

    return response.json()['puuid']

def get_name_and_tag(puuid=None, api_key=None):
    link = f'https://europe.api.riotgames.com/riot/account/v1/accounts/by-puuid/{puuid}?api_key={api_key}'

    response = requests.get(link)
    response.json()

    gameName = response.json()['gameName']
    tagLine = response.json()['tagLine']

    return f'{gameName}#{tagLine}'

# %%
get_puuid(gameName, tagLine, api_key)
# Out:
# 'sYgaAEq5FqgCqn7iIse8zzNHhmQ8CbQP4YVR-Lyg5ZQT_UvjRriqWzHTzHbG2pO_k74mXuHuQw5rJw'

# %%
get_name_and_tag(puuid=get_puuid(gameName, tagLine, api_key), api_key=api_key)
# Out:
# 'LordVoItage#EUW'

# %% [markdown]
# ### **3. Retrieving the SoloQ Ladder**

# %%
response = requests.get(f'https://euw1.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={api_key}')

puuid = response.json()['entries'][0]['puuid']

summoner_name = get_name_and_tag(puuid, api_key)

summoner_name
# Out:
# 'G2 SkewMond#3327'

# %%
import pandas as pd

def get_ladder(top=None, api_key=None):
    root = 'https://euw1.api.riotgames.com/'
    chall = 'lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5'
    gmaster = 'lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5'
    master = 'lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5'

    chall_response = requests.get(root + chall + '?api_key=' + api_key)
    gmaster_response = requests.get(root + gmaster + '?api_key=' + api_key)
    master_response = requests.get(root + master + '?api_key=' + api_key)

    chall_df = pd.DataFrame(chall_response.json()['entries']).sort_values('leaguePoints', ascending=False).reset_index(drop=True)
    gmaster_df = pd.DataFrame(gmaster_response.json()['entries']).sort_values('leaguePoints', ascending=False).reset_index(drop=True)
    master_df = pd.DataFrame(master_response.json()['entries']).sort_values('leaguePoints', ascending=False).reset_index(drop=True)
    ladder = pd.concat([chall_df, gmaster_df, master_df], keys=['Challenger', 'Grandmaster', 'Master'])[:top].reset_index(drop=True)

    ladder = ladder.drop(columns='rank').reset_index(drop=False).rename(columns={'index': 'rank'})
    ladder['rank'] += 1

    return ladder

# %%
ladder = get_ladder(top=10, api_key=api_key)

# %%
ladder['summoner_name'] = ladder['puuid'].apply(lambda x: get_name_and_tag(x, api_key))

# %%
ladder
# Out:
#    rank                                         summonerId  \
# 0     1   aWgR5OW8ruiR-BZy2CmyE01u6iWSsiZrTO_JJ5tVK01_oriX
# 1     2  fpCdtOdci7tnvJDPdNC1U6KDRs_lq64Op6mqeUyKVLlzrd...
# 2     3    8G_VDEDjVDXP9mXgESWI_9bILOaUnPHsrhB6PJnwbqse97o
# 3     4    0fPtqO_Ptj8EiqYaGlbv5Z6wZ6D_7oYqnMJmeTlNF7FIeQw
# 4     5  iTeb8_FNg2J4aDakvghhJUbm-002iasywLms0iUF_4PM7n...
# 5     6   ujQ7AWE6GNKTVHk1wkjX4agW3qBdd3t82CXBWBruAB5jcS9k
# 6     7    9BSiPqVSq27Var4YFNZaqabQsXODdH2XSi02ZzNCBMhGo5Y
# 7     8   SMdG7MT4Pc3ruok6Z4IPA9ZhwlBAot8Le5zxZqPKsqNFHgjE
# 8     9   KHBIZVoYC50_YO0oSJ5rXtBErZL8kIozDAXJIiYlWcJkdCGt
# 9    10   5mPvdoGCJoaSNr3Sc8LCn_srhWnYC9YDU3opWVqfsSO_kGfs
#
#                                                puuid  leaguePoints  wins  \
# 0  vGfPE8LWdIKRLLC0huTNYNKwSJ4dyesDd4J5tVy8LSUNUl...          2131   187
# 1  ZhxdGQCRKO7k1FUjbQfGO2Ln-Dxl4n9oA9txYN2rqhoyis...          1875   234
# 2  Az2f_S0MvTr-7m97Wsiyj_i0ZGKSPrG9hIXJv5tSYYG4sg...          1710   129
# 3  QtOWvEaM-3H3cFdQLbH3qILSwZDBbcQOaT4-aTSNEZWjVV...          1700   155
# 4  HAJ71n_egQn7Dkfw9y6CXPQ9N4Cnrdxm1j5RIpbIjaieL2...          1679   240
# 5  wQ3sHQG8e56XQa_zEUsnMOVihPr4v2pnsb2HkZjuFfWleY...          1593   130
# 6  Fn2pIdf1zFAtFPBUicQdoztmbEDoUxV1W8pnc6Sc_LbeCl...          1582   155
# 7  JysLF52n9WgPlvK4ecAuCUId-ILYS0U-kd4obqmSB0YL9t...          1579   199
# 8  7PHuKgmARX_YeXzyRninl-SriUyX9E4PKa44ckoLdv630B...          1557   113
# 9  TL0sOMds7kvWSKxxfCmiZRphzERZCv2CEwfQ42r_IiRhrv...          1556   213
#
#    losses  veteran  inactive  freshBlood  hotStreak       summoner_name
# 0     125     True     False       False      False    G2 SkewMond#3327
# 1     179     True     False       False      False          J1HUIV#000
# 2      80     True     False       False       True        Odysseus#131
# 3     112     True     False       False      False      G2 Labrov#8085
# 4     160     True     False       False      False          Ivory#EfEf
# 5      86     True     False       False      False   TwTv Phantasm#103
# 6     115     True     False       False      False  G2 Hans Sama#12838
# 7     164     True     False       False      False           Tοαst#EUW
# 8      79     True     False       False      False  KC NEXT ADKING#EUW
# 9     141     True     False       False      False         Vetheø#4321

# %% [markdown]
# ### **4. Obtaining Match Histories**

# %%
def get_match_history(puuid=None, api_key=None, start=0, count=20):

    root = 'https://europe.api.riotgames.com/'
    endpoint = f'lol/match/v5/matches/by-puuid/{puuid}/ids'
    query_params = f'?type=ranked&start={start}&count={count}'

    response = requests.get(root + endpoint + query_params + '&api_key=' + api_key)

    return response.json()

def get_match_data_from_id(matchId=None, api_key=None):

    root = 'https://europe.api.riotgames.com/'
    endpoint = f'lol/match/v5/matches/{matchId}'

    response = requests.get(root + endpoint + '?api_key=' + api_key)

    return response.json()

# %%
puuid = get_puuid(gameName, tagLine, api_key)
matchId = get_match_history(puuid, api_key, start=0, count=100)[0]

get_match_data_from_id(matchId, api_key)
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_7317675815',
#   'participants': ['9yECzY_qZRykY05W1qz37r4loWBQjA0gF3rNuEuqqHmtloyDeg2I4LpTm5sT9L2uMp-oIjB8_BfNdg',
#    'U7aHYNfy8KKaGl46wvJA24ag-TYUOcGin_ARtlniAnxpjdpK1NZvdKUcdsEb1CYWrKBHXFT4zNQXPQ',
#    '6hBf0MBsJkWo4vTDXJ6WM2u024Ww04JSMDsD06xf9zR4xiT7O7Pg59ZT-3O644mM4-Fl_a2NaCHYhQ',
#    'NEzHGIamYgeOxvlJSxCjhYjK89xHCvXlueQyJVVQQwFL9EA5XN0Tjqb6CSNZxiwezhrGW4KBUAGSOw',
#    '7rnquCJUtUU17bYV9tweVpi1HzfvdICy0csPEMcTqgwjwPB2ra8MaTBU5Ci4Goch51zHROkLTCc_uQ',
#    'H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoMECtc68UQKDURkNLNvDo68UU9pEUkMHEog',
#    'sYgaAEq5FqgCqn7iIse8zzNHhmQ8CbQP4YVR-Lyg5ZQT_UvjRriqWzHTzHbG2pO_k74mXuHuQw5rJw',
#    '7J7ikEoyDFQMEQeNojtzE_LIjeW2qJZXirGZuZn_olvip6yaRxyeHUcuG4YJxt22UZMqTufcbf0hMg',
#    'On8aKn4RxhweTnG6bsL_WiJuXoJRpLdEToYTT0L7_3xqz-uOPKgt-f7SaBKhLvm12p_y4YyOgU9inw',
#    'IvzgjokXfwX4uQv52XMWmIAKYdkYF38QkoNi7bdkSbfNqxFyAZVw4lQIz6yk6Hj2ZxcCkW_lYXMnzw']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1740410317834,
#   'gameDuration': 1703,
#   'gameEndTimestamp': 1740412053643,
#   'gameId': 7317675815,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-7317675815',
#   'gameStartTimestamp': 1740410350088,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '15.4.657.5386',
#   'mapId': 11,
#   'participants': [{'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 2,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 3,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 275.5546646118164,
#      'InfernalScalePickup': 25,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 145,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 477.81883297720043,
#      'damageTakenOnTeamPercentage': 0.211709557350157,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 7,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 12,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 862.5731077840001,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1703.8929249260002,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 357.2039282457746,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.29411764705882354,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 69,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6631, 3742],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 10,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 2,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 44,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'soloTurretsLategame': 2,
#      'stealthWardsPlaced': 8,
#      'survivedSingleDigitHpCount': 1,
#      'survivedThreeImmobilizesInFight': 9,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 5,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 0,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.156963658279099,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.20645803213119507,
#      'visionScorePerMinute': 0.43460994618579585,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 13879,
#     'champLevel': 15,
#     'championId': 122,
#     'championName': 'Darius',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 8674,
#     'damageDealtToObjectives': 8674,
#     'damageDealtToTurrets': 8674,
#     'damageSelfMitigated': 21730,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 4,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10143,
#     'goldSpent': 9450,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 1055,
#     'item1': 3047,
#     'item2': 3742,
#     'item3': 6631,
#     'item4': 2021,
#     'item5': 1028,
#     'item6': 3340,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 3,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 521,
#     'magicDamageDealt': 0,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 7214,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 215, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 745, 'var2': 100, 'var3': 0},
#         {'perk': 9105, 'var1': 21, 'var2': 50, 'var3': 0},
#         {'perk': 8299, 'var1': 822, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8446, 'var1': 2046, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 1060, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 111008,
#     'physicalDamageDealtToChampions': 12006,
#     'physicalDamageTaken': 16774,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6767,
#     'pushPings': 0,
#     'puuid': '9yECzY_qZRykY05W1qz37r4loWBQjA0gF3rNuEuqqHmtloyDeg2I4LpTm5sT9L2uMp-oIjB8_BfNdg',
#     'quadraKills': 0,
#     'retreatPings': 1,
#     'riotIdGameName': 'TaPadPo',
#     'riotIdTagline': '2468',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 68,
#     'spell2Casts': 59,
#     'spell3Casts': 14,
#     'spell4Casts': 4,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 6,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'P4pBVd37C2Eb-PsLabfZX1NxzaM4XgerdnoHptOXhlAhPR7F',
#     'summonerLevel': 930,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 17,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 113905,
#     'totalDamageDealtToChampions': 13569,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 24272,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 5108,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 203,
#     'totalTimeCCDealt': 83,
#     'totalTimeSpentDead': 98,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2897,
#     'trueDamageDealtToChampions': 1562,
#     'trueDamageTaken': 283,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 12,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 1,
#     'wardsPlaced': 8,
#     'win': False},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 3,
#     'assists': 5,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 8,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 38,
#      'InfernalScalePickup': 18,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 472,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 680.6175689697266,
#      'buffsStolen': 9,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.3730092369047208,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 762.1988767245468,
#      'damageTakenOnTeamPercentage': 0.29745373042006773,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 16,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 232.91839599609375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 15,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 862.5731077840001,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1703.8929249260002,
#      'goldPerMinute': 418.50499223328205,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 4,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 68.00000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.625,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.7647058823529411,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 3,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 3,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 1,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6692, 3814, 6701],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 17.250000089406967,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 102,
#      'skillshotsHit': 21,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 12,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 13,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2503826048074867,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.48624372482299805,
#      'visionScorePerMinute': 0.7972482852139582,
#      'voidMonsterKill': 5,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 12251,
#     'champLevel': 14,
#     'championId': 64,
#     'championName': 'LeeSin',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 10463,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 30329,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 9,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11884,
#     'goldSpent': 11750,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6701,
#     'item1': 6692,
#     'item2': 3158,
#     'item3': 3814,
#     'item4': 3044,
#     'item5': 3067,
#     'item6': 3340,
#     'itemsPurchased': 22,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 528,
#     'magicDamageDealt': 40552,
#     'magicDamageDealtToChampions': 3658,
#     'magicDamageTaken': 7786,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 153,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 9,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 1281, 'var2': 0, 'var3': 0},
#         {'perk': 8143, 'var1': 983, 'var2': 0, 'var3': 0},
#         {'perk': 8140, 'var1': 13, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 320, 'var2': 4, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 119817,
#     'physicalDamageDealtToChampions': 16560,
#     'physicalDamageTaken': 25416,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 786,
#     'pushPings': 3,
#     'puuid': 'U7aHYNfy8KKaGl46wvJA24ag-TYUOcGin_ARtlniAnxpjdpK1NZvdKUcdsEb1CYWrKBHXFT4zNQXPQ',
#     'quadraKills': 0,
#     'retreatPings': 1,
#     'riotIdGameName': 'The Cat Gaia',
#     'riotIdTagline': '2311',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 190,
#     'spell2Casts': 151,
#     'spell3Casts': 123,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 20,
#     'summoner2Id': 11,
#     'summonerId': 'ymK_CP02hDW4_VKioiWepvQqtap0Nbfk5hYO7ZlB24CV8qA',
#     'summonerLevel': 153,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 15,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 229188,
#     'totalDamageDealtToChampions': 21645,
#     'totalDamageShieldedOnTeammates': 232,
#     'totalDamageTaken': 34103,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 13650,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 15,
#     'totalTimeCCDealt': 483,
#     'totalTimeSpentDead': 227,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 68817,
#     'trueDamageDealtToChampions': 1425,
#     'trueDamageTaken': 901,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 22,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 0,
#     'wardsPlaced': 14,
#     'win': False},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 1,
#     'assistMePings': 6,
#     'assists': 7,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 3,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 216,
#      'InfernalScalePickup': 12,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 273,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 119.15716552734375,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7851280871473185,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 922.9381667679013,
#      'damageTakenOnTeamPercentage': 0.1668851141706841,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 8,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 862.5731077840001,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1703.8929249260002,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 405.3315742199554,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.6666666666666667,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.5882352941176471,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 80,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [2503, 6653, 3116],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 39,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 44,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 10,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.3031855193288446,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 4,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.3473975658416748,
#      'visionScorePerMinute': 0.6002686482497349,
#      'voidMonsterKill': 5,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 14022,
#     'champLevel': 15,
#     'championId': 90,
#     'championName': 'Malzahar',
#     'championTransform': 0,
#     'commandPings': 9,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 2703,
#     'damageDealtToObjectives': 6617,
#     'damageDealtToTurrets': 2703,
#     'damageSelfMitigated': 13644,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 10,
#     'enemyVisionPings': 9,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11510,
#     'goldSpent': 10650,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6653,
#     'item1': 3116,
#     'item2': 3916,
#     'item3': 2503,
#     'item4': 0,
#     'item5': 3020,
#     'item6': 3363,
#     'itemsPurchased': 20,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 716,
#     'magicDamageDealt': 135883,
#     'magicDamageDealtToChampions': 25762,
#     'magicDamageTaken': 5196,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 1,
#     'neutralMinionsKilled': 6,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 10,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5013, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1694, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 705, 'var3': 0},
#         {'perk': 8210, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 641, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 11640,
#     'physicalDamageDealtToChampions': 447,
#     'physicalDamageTaken': 13324,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3546,
#     'pushPings': 0,
#     'puuid': '6hBf0MBsJkWo4vTDXJ6WM2u024Ww04JSMDsD06xf9zR4xiT7O7Pg59ZT-3O644mM4-Fl_a2NaCHYhQ',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'iInted a Fish',
#     'riotIdTagline': 'EUW',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 89,
#     'spell2Casts': 82,
#     'spell3Casts': 91,
#     'spell4Casts': 11,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 12,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'xBA1Xq29YvjmjuJiJPtc-dtHqaDiSZkNtZpOdXv763DEb1LaHJb4KXJuOQ',
#     'summonerLevel': 74,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 51,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 164123,
#     'totalDamageDealtToChampions': 26209,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19133,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 600,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 210,
#     'totalTimeCCDealt': 405,
#     'totalTimeSpentDead': 240,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 16599,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 612,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 1,
#     'wardsPlaced': 13,
#     'win': False},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 3,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 0,
#      'InfernalScalePickup': 14,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 122,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 257.3145751953125,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 500.6888192553536,
#      'damageTakenOnTeamPercentage': 0.16387554190605277,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 13,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 6,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 862.5731077840001,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1703.8929249260002,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 354.13337465950553,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.625,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.29411764705882354,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 1,
#      'laneMinionsFirst10Minutes': 75,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3032, 3046],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 43,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 5,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 87,
#      'skillshotsHit': 40,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 5,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 0,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.16447645698702063,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.2706056833267212,
#      'visionScorePerMinute': 0.5014971087607467,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11869,
#     'champLevel': 14,
#     'championId': 22,
#     'championName': 'Ashe',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 613,
#     'damageDealtToObjectives': 613,
#     'damageDealtToTurrets': 613,
#     'damageSelfMitigated': 9821,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10056,
#     'goldSpent': 9300,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 1055,
#     'item1': 3032,
#     'item2': 1038,
#     'item3': 3006,
#     'item4': 3046,
#     'item5': 1018,
#     'item6': 3340,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 294,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 668,
#     'magicDamageDealt': 2542,
#     'magicDamageDealtToChampions': 2042,
#     'magicDamageTaken': 8266,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 3,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 373, 'var2': 373, 'var3': 0},
#         {'perk': 8009, 'var1': 896, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 22, 'var2': 0, 'var3': 0},
#         {'perk': 8017, 'var1': 707, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8410, 'var1': 71, 'var2': 0, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 180}],
#        'style': 8300}]},
#     'physicalDamageDealt': 101844,
#     'physicalDamageDealtToChampions': 11761,
#     'physicalDamageTaken': 10043,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5179,
#     'pushPings': 0,
#     'puuid': 'NEzHGIamYgeOxvlJSxCjhYjK89xHCvXlueQyJVVQQwFL9EA5XN0Tjqb6CSNZxiwezhrGW4KBUAGSOw',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'Luler x UwUzi',
#     'riotIdTagline': 'EUW',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 30,
#     'spell2Casts': 74,
#     'spell3Casts': 11,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 21,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'DjY9JC8hSZe53SFCqaeLRr4Fvqd5JnClCWC7QMdw4Vev0FTEhMZPK5qfOQ',
#     'summonerLevel': 74,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 28,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 116902,
#     'totalDamageDealtToChampions': 14218,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 18788,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 842,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 219,
#     'totalTimeCCDealt': 650,
#     'totalTimeSpentDead': 276,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 12515,
#     'trueDamageDealtToChampions': 414,
#     'trueDamageTaken': 478,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 14,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 4,
#     'wardsPlaced': 5,
#     'win': False},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 7,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 64,
#      'InfernalScalePickup': 18,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 155,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 362.64874267578125,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 380.49200582654356,
#      'damageTakenOnTeamPercentage': 0.16007605615303835,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 5285.0986328125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 37,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 862.5731077840001,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1703.8929249260002,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 248.27728548413478,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 2,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.8888888888888888,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.47058823529411764,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 10,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [2065, 3871, 4005],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 8,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 14,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 27,
#      'skillshotsHit': 28,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 16,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 8,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.12499176059754909,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.28759920597076416,
#      'visionScorePerMinute': 1.8973246564845507,
#      'voidMonsterKill': 3,
#      'wardTakedowns': 9,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 2},
#     'champExperience': 9327,
#     'champLevel': 12,
#     'championId': 40,
#     'championName': 'Janna',
#     'championTransform': 0,
#     'commandPings': 9,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 113,
#     'damageDealtToObjectives': 644,
#     'damageDealtToTurrets': 113,
#     'damageSelfMitigated': 9425,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 5,
#     'goldEarned': 7050,
#     'goldSpent': 6175,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3871,
#     'item1': 2065,
#     'item2': 4005,
#     'item3': 0,
#     'item4': 0,
#     'item5': 3009,
#     'item6': 3364,
#     'itemsPurchased': 20,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 444,
#     'magicDamageDealt': 13073,
#     'magicDamageDealtToChampions': 8613,
#     'magicDamageTaken': 5251,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 2,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 9,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1223, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 224, 'var3': 0},
#         {'perk': 8210, 'var1': 1, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 471, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 635, 'var2': 0, 'var3': 0},
#         {'perk': 8105, 'var1': 32, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 4418,
#     'physicalDamageDealtToChampions': 1000,
#     'physicalDamageTaken': 12733,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4568,
#     'pushPings': 0,
#     'puuid': '7rnquCJUtUU17bYV9tweVpi1HzfvdICy0csPEMcTqgwjwPB2ra8MaTBU5Ci4Goch51zHROkLTCc_uQ',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'iZi ChØzen',
#     'riotIdTagline': 'EUW',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 73,
#     'spell2Casts': 29,
#     'spell3Casts': 47,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 14,
#     'summonerId': 'HbGeSND45WHsl6wlzkmkl8lmURLtlsnf_mBcZ0L1M9P9GF4',
#     'summonerLevel': 419,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 37,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 20720,
#     'totalDamageDealtToChampions': 10805,
#     'totalDamageShieldedOnTeammates': 3341,
#     'totalDamageTaken': 18352,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3590,
#     'totalHealsOnTeammates': 1943,
#     'totalMinionsKilled': 26,
#     'totalTimeCCDealt': 108,
#     'totalTimeSpentDead': 217,
#     'totalUnitsHealed': 7,
#     'tripleKills': 0,
#     'trueDamageDealt': 3228,
#     'trueDamageDealtToChampions': 1191,
#     'trueDamageTaken': 368,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 53,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 9,
#     'wardsPlaced': 19,
#     'win': False},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 6,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 13,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 0,
#      'InfernalScalePickup': 8,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 381,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
# ...
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 7,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.16616821511140586,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 3,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.3710005283355713,
#      'visionScorePerMinute': 0.6875527945595318,
#      'voidMonsterKill': 2,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 1},
#     'champExperience': 14813,
#     'champLevel': 16,
#     'championId': 21,
#     'championName': 'MissFortune',
#     'championTransform': 0,
#     'commandPings': 10,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 8059,
#     'damageDealtToObjectives': 37207,
#     'damageDealtToTurrets': 8059,
#     'damageSelfMitigated': 4269,
#     'dangerPings': 0,
#     'deaths': 1,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12712,
#     'goldSpent': 11000,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 1055,
#     'item1': 2422,
#     'item2': 3031,
#     'item3': 6676,
#     'item4': 3033,
#     'item5': 1018,
#     'item6': 3340,
#     'itemsPurchased': 16,
#     'killingSprees': 1,
#     'kills': 10,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 1020,
#     'largestKillingSpree': 9,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 956,
#     'magicDamageDealt': 1076,
#     'magicDamageDealtToChampions': 579,
#     'magicDamageTaken': 3755,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 13,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 584, 'var2': 384, 'var3': 0},
#         {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8313, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8224, 'var1': 76, 'var2': 317, 'var3': 0},
#         {'perk': 8236, 'var1': 14, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 143577,
#     'physicalDamageDealtToChampions': 14371,
#     'physicalDamageTaken': 5941,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6667,
#     'pushPings': 0,
#     'puuid': 'On8aKn4RxhweTnG6bsL_WiJuXoJRpLdEToYTT0L7_3xqz-uOPKgt-f7SaBKhLvm12p_y4YyOgU9inw',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'Oma Desala',
#     'riotIdTagline': 'EUW',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 78,
#     'spell2Casts': 69,
#     'spell3Casts': 17,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 6,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'kaRoyHr32HC_W-NLXhu5eJBUVbwMkgx-0rGJQ2Z-YH--gSqB',
#     'summonerLevel': 944,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 4,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 151059,
#     'totalDamageDealtToChampions': 15755,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 9769,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 2843,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 174,
#     'totalTimeCCDealt': 71,
#     'totalTimeSpentDead': 25,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 6406,
#     'trueDamageDealtToChampions': 803,
#     'trueDamageTaken': 71,
#     'turretKills': 4,
#     'turretTakedowns': 5,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 19,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 2,
#     'wardsPlaced': 11,
#     'win': True},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 11,
#     'assists': 22,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'HealFromMapSources': 32,
#      'InfernalScalePickup': 23,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 241,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6656165340842974,
#      'controlWardsPlaced': 5,
#      'damagePerMinute': 173.45082342671873,
#      'damageTakenOnTeamPercentage': 0.13499597600776347,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 2,
#      'doubleAces': 0,
#      'dragonTakedowns': 3,
#      'earliestBaron': 1644.3861986200002,
#      'earliestDragonTakedown': 461.78060785800005,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 1525.646240234375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 14,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 1703.8929249260002,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 285.79621713312696,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5.5,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.6111111111111112,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 6,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3876, 2065, 3003, 3040],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 3,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 1,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 33,
#      'skillshotsHit': 42,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 21,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.051949349206729716,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 3,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 5,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 1,
#      'visionScoreAdvantageLaneOpponent': 0.40370428562164307,
#      'visionScorePerMinute': 2.663282734503707,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 1},
#     'champExperience': 12009,
#     'champLevel': 14,
#     'championId': 26,
#     'championName': 'Zilean',
#     'championTransform': 0,
#     'commandPings': 13,
#     'consumablesPurchased': 8,
#     'damageDealtToBuildings': 4490,
#     'damageDealtToObjectives': 5290,
#     'damageDealtToTurrets': 4490,
#     'damageSelfMitigated': 6510,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 5,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 7,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 8116,
#     'goldSpent': 8050,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3876,
#     'item1': 2065,
#     'item2': 0,
#     'item3': 3040,
#     'item4': 2055,
#     'item5': 3170,
#     'item6': 3364,
#     'itemsPurchased': 26,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 642,
#     'magicDamageDealt': 11017,
#     'magicDamageDealtToChampions': 3611,
#     'magicDamageTaken': 5669,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 49,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 625, 'var2': 1048, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 220, 'var3': 0},
#         {'perk': 8210, 'var1': 14, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 7, 'var2': 20, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 372, 'var2': 0, 'var3': 0},
#         {'perk': 8105, 'var1': 40, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 5348,
#     'physicalDamageDealtToChampions': 941,
#     'physicalDamageTaken': 10269,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6254,
#     'pushPings': 0,
#     'puuid': 'IvzgjokXfwX4uQv52XMWmIAKYdkYF38QkoNi7bdkSbfNqxFyAZVw4lQIz6yk6Hj2ZxcCkW_lYXMnzw',
#     'quadraKills': 0,
#     'retreatPings': 1,
#     'riotIdGameName': 'BAWSZITOOO',
#     'riotIdTagline': 'EUWZ',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 109,
#     'spell2Casts': 42,
#     'spell3Casts': 84,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 7,
#     'summonerId': 'GkKjC7gsoRAtqbm-oRSMMmh7V19y2PRK_THNKiPBufRCh88MEX9N7mwyEg',
#     'summonerLevel': 488,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 14,
#     'timePlayed': 1703,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 21850,
#     'totalDamageDealtToChampions': 4925,
#     'totalDamageShieldedOnTeammates': 1134,
#     'totalDamageTaken': 16899,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 5084,
#     'totalHealsOnTeammates': 391,
#     'totalMinionsKilled': 20,
#     'totalTimeCCDealt': 80,
#     'totalTimeSpentDead': 53,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 5485,
#     'trueDamageDealtToChampions': 372,
#     'trueDamageTaken': 959,
#     'turretKills': 1,
#     'turretTakedowns': 5,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 75,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 3,
#     'wardsPlaced': 32,
#     'win': True}],
#   'platformId': 'EUW1',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 800, 'pickTurn': 1},
#      {'championId': 799, 'pickTurn': 2},
#      {'championId': 119, 'pickTurn': 3},
#      {'championId': 777, 'pickTurn': 4},
#      {'championId': 134, 'pickTurn': 5}],
#     'feats': {'EPIC_MONSTER_KILL': {'featState': 1001},
#      'FIRST_BLOOD': {'featState': 1001},
#      'FIRST_TURRET': {'featState': 1}},
#     'objectives': {'atakhan': {'first': False, 'kills': 0},
#      'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 17},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': False, 'kills': 5},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 4}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [{'championId': 86, 'pickTurn': 6},
#      {'championId': 119, 'pickTurn': 7},
#      {'championId': 56, 'pickTurn': 8},
#      {'championId': 134, 'pickTurn': 9},
#      {'championId': 111, 'pickTurn': 10}],
#     'feats': {'EPIC_MONSTER_KILL': {'featState': 3},
#      'FIRST_BLOOD': {'featState': 3},
#      'FIRST_TURRET': {'featState': 1001}},
#     'objectives': {'atakhan': {'first': True, 'kills': 1},
#      'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 36},
#      'dragon': {'first': True, 'kills': 4},
#      'horde': {'first': True, 'kills': 1},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': False, 'kills': 10}},
#     'teamId': 200,
#     'win': True}],
#   'tournamentCode': ''}}

# %% [markdown]
# ### **5. Processing SoloQ Matches**

# %%
def process_match_json(match_json, puuid=None):

    ## Architecture
    metadata = match_json['metadata']
    info = match_json['info']
    players = info['participants']
    participants = metadata['participants']
    teams = info['teams']
    player = players[participants.index(puuid)]
    perks = player['perks']
    stats = perks['statPerks']
    styles = perks['styles']

    primary = styles[0]
    secondary = styles[1]

    match_id = metadata['matchId']

    ## Data
    game_creation = info['gameCreation']
    game_duration = info['gameDuration']
    game_start_timestamp = info['gameStartTimestamp']
    game_end_timestamp = info['gameEndTimestamp']
    patch = info['gameVersion']

    riot_id = player['riotIdGameName']
    riot_tag = player['riotIdTagline']
    summoner_id = player['summonerId']
    summoner_name = player['summonerName']

    win = player['win']

    champ_id = player['championId']
    champ_transform = player['championTransform']
    champ_level = player['champLevel']

    gold_earned = player['goldEarned']
    neutral_minions_killed = player['neutralMinionsKilled']
    total_minions_killed = player['totalMinionsKilled']

    kills = player['kills']
    deaths = player['deaths']
    assists = player['assists']
    first_blood = player['firstBloodKill']

    total_damage_dealt = player['totalDamageDealt']
    total_damage_shielded = player['totalDamageShieldedOnTeammates']
    total_damage_taken = player['totalDamageTaken']
    total_time_cc_dealt = player['totalTimeCCDealt']

    early_surrender = player['gameEndedInEarlySurrender']
    surrender = player['gameEndedInSurrender']

    item0 = player['item0']
    item1 = player['item1']
    item2 = player['item2']
    item3 = player['item3']
    item4 = player['item4']
    item5 = player['item5']
    item6 = player['item6']

    summoner_1_id = player['summoner1Id']
    summoner_2_id = player['summoner2Id']

    wards_placed = player['wardsPlaced']
    wards_killed = player['wardsKilled']
    vision_score = player['visionScore']

    objectives_stolen = player['objectivesStolen']
    objectives_stolen_assists = player['objectivesStolenAssists']

    defense = stats['defense']
    flex = stats['flex']
    offense = stats['offense']

    primary_style = primary['style']
    secondary_style = primary['style']

    primary_keystone = primary['selections'][0]['perk']
    primary_perk_1  = primary['selections'][1]['perk']
    primary_perk_2  = primary['selections'][2]['perk']
    primary_perk_3  = primary['selections'][3]['perk']

    secondary_perk_1 = secondary['selections'][0]['perk']
    secondary_perk_2 = secondary['selections'][1]['perk']

    #for team in teams:
    #    if team['teamId'] == player['teamId']:
    #        objs = team['objectives']
    #        baron = objs['baron']
    #        dragon = objs['dragon']
    #        grubs = objs['horde']
    #        rift_herald = objs['riftHerald']
    #        tower = objs['tower']
    #        inhibitor = objs['inhibitor']
    

    match_df = pd.DataFrame({
        'match_id': [match_id],
        'participants': [participants],
        'game_creation': [game_creation],
        'game_duration': [game_duration],
        'game_start_timestamp': [game_start_timestamp],
        'game_end_timestamp': [game_end_timestamp],
        'patch': [patch],
        'riot_id': [riot_id],
        'riot_tag': [riot_tag],
        'summoner_id': [summoner_id],
        'summoner_name': [summoner_name],
        'win': [win],
        'champ_id': [champ_id],
        'champ_transform': [champ_transform],
        'champ_level': [champ_level],
        'gold_earned': [gold_earned],
        'neutral_minions_killed': [neutral_minions_killed],
        'total_minions_killed': [total_minions_killed],
        'kills': [kills],
        'deaths': [deaths],
        'assists': [assists],
        'first_blood': [first_blood],
        'total_damage_dealt': [total_damage_dealt],
        'total_damage_shielded': [total_damage_shielded],
        'total_damage_taken': [total_damage_taken],
        'total_time_cc_dealt': [total_time_cc_dealt],
        'early_surrender': [early_surrender],
        'surrender': [surrender],
        'item0': [item0],
        'item1': [item1],
        'item2': [item2],
        'item3': [item3],
        'item4': [item4],
        'item5': [item5],
        'item6': [item6],
        'summoner_1_id': [summoner_1_id],
        'summoner_2_id': [summoner_2_id],
        'wards_placed': [wards_placed],
        'wards_killed': [wards_killed],
        'vision_score': [vision_score],
        'objectives_stolen': [objectives_stolen],
        'objectives_stolen_assists': [objectives_stolen_assists],
        'defense': [defense],
        'flex': [flex],
        'offense': [offense],
        'primary_style': [primary_style],
        'secondary_style': [secondary_style],
        'primary_keystone': [primary_keystone],
        'primary_perk_1': [primary_perk_1],
        'primary_perk_2': [primary_perk_2],
        'primary_perk_3': [primary_perk_3],
        'secondary_perk_1': [secondary_perk_1],
        'secondary_perk_2': [secondary_perk_2],
        })
    return match_df

# %%
gameName = 'LordVoItage'
tagLine = 'EUW'
api_key = os.environ.get('riot_api_key')

puuid = get_puuid(gameName, tagLine, api_key)
matchId = get_match_history(puuid, api_key, start=0, count=100)[2]

game = get_match_data_from_id(matchId, api_key)

process_match_json(game, puuid)
# Out:
#           match_id                                       participants  \
# 0  EUW1_7315801214  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
#
#    game_creation  game_duration  game_start_timestamp  game_end_timestamp  \
# 0  1740258651379           1830         1740258775404       1740260605495
#
#            patch      riot_id riot_tag  \
# 0  15.4.657.5386  LordVoItage      EUW
#
#                                        summoner_id  ...  flex  offense  \
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg  ...  5008     5008
#
#    primary_style  secondary_style  primary_keystone  primary_perk_1  \
# 0           8100             8100              8128            8143
#
#    primary_perk_2  primary_perk_3  secondary_perk_1  secondary_perk_2
# 0            8140            8135              9111              8014
#
# [1 rows x 53 columns]

# %%
match_ids = get_match_history(puuid, api_key, start=0, count=5)

df = pd.DataFrame()
for match_id in match_ids:
    match = get_match_data_from_id(match_id, api_key)
    match_df = process_match_json(match, puuid)
    
    df = pd.concat([df, match_df])

# %%
df
# Out:
#           match_id                                       participants  \
# 0  EUW1_7317675815  [9yECzY_qZRykY05W1qz37r4loWBQjA0gF3rNuEuqqHmtl...
# 0  EUW1_7316614390  [ane_rqP8NlA6dPk3xjdamKA91ZALfRyVekIxSmWI6YCbV...
# 0  EUW1_7315801214  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
# 0  EUW1_7315747405  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
# 0  EUW1_7311182902  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
#
#    game_creation  game_duration  game_start_timestamp  game_end_timestamp  \
# 0  1740410317834           1703         1740410350088       1740412053643
# 0  1740325731450           1597         1740325754586       1740327352070
# 0  1740258651379           1830         1740258775404       1740260605495
# 0  1740256517587           1719         1740256568697       1740258288305
# 0  1739908043173           2410         1739908071002       1739910481503
#
#            patch      riot_id riot_tag  \
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.3.656.4086  LordVoItage      EUW
#
#                                        summoner_id  ...  flex  offense  \
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg  ...  5008     5008
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg  ...  5008     5008
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg  ...  5008     5008
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg  ...  5008     5008
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg  ...  5008     5008
#
#    primary_style  secondary_style  primary_keystone  primary_perk_1  \
# 0           8100             8100              8128            8143
# 0           8100             8100              8128            8143
# 0           8100             8100              8128            8143
# 0           8100             8100              8128            8143
# 0           8100             8100              8128            8143
#
#    primary_perk_2  primary_perk_3  secondary_perk_1  secondary_perk_2
# 0            8140            8135              9111              8014
# 0            8140            8135              9111              8014
# 0            8140            8135              9111              8014
# 0            8140            8135              9111              8014
# 0            8140            8135              9111              8014
#
# [5 rows x 53 columns]

# %% [markdown]
# ### **6. Utlising Community Dragon**

# %%
perk = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/perks.json'
perk_styles = 'https://raw.communitydragon.org/latest/plugins/rcp-be-lol-game-data/global/default/v1/perkstyles.json'

perk_json = requests.get(perk).json()
perk_styles_json = requests.get(perk_styles).json()

# %%
def json_extract(obj, key):

    arr = []

    def extract(obj, arr, key):
        if isinstance(obj, dict):
            for k, v in obj.items():
                if k == key:
                    arr.append(v)
                elif isinstance(v, (dict, list)):
                    extract(v, arr, key)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, key)

        return arr
    
    values = extract(obj, arr, key)
    return values

# %%
perk_ids = json_extract(perk_json, 'id')
perk_names = json_extract(perk_json, 'name')

# perk_dict = dict(map(lambda x, y: (x, y), perk_ids, perk_names))
perk_dict = dict(zip(perk_ids, perk_names))


perk_styles_ids = json_extract(perk_styles_json, 'id')
perk_styles_names = json_extract(perk_styles_json, 'name')

perk_styles_dict = dict(map(lambda x, y: (int(x), y), perk_styles_ids, perk_styles_names))
# perk_styles_dict = dict(zip(perk_styles_ids, perk_styles_names))

# %%
pd.options.display.max_columns = 100

df = df.replace(perk_dict).replace(perk_styles_dict)

df
# Out:
#           match_id                                       participants  \
# 0  EUW1_7317675815  [9yECzY_qZRykY05W1qz37r4loWBQjA0gF3rNuEuqqHmtl...
# 0  EUW1_7316614390  [ane_rqP8NlA6dPk3xjdamKA91ZALfRyVekIxSmWI6YCbV...
# 0  EUW1_7315801214  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
# 0  EUW1_7315747405  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
# 0  EUW1_7311182902  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
#
#    game_creation  game_duration  game_start_timestamp  game_end_timestamp  \
# 0  1740410317834           1703         1740410350088       1740412053643
# 0  1740325731450           1597         1740325754586       1740327352070
# 0  1740258651379           1830         1740258775404       1740260605495
# 0  1740256517587           1719         1740256568697       1740258288305
# 0  1739908043173           2410         1739908071002       1739910481503
#
#            patch      riot_id riot_tag  \
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.4.657.5386  LordVoItage      EUW
# 0  15.3.656.4086  LordVoItage      EUW
#
#                                        summoner_id summoner_name    win  \
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg                 True
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg                 True
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg                 True
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg                 True
# 0  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg                False
#
#    champ_id  champ_transform  champ_level  gold_earned  \
# 0       121                0           16        12783
# 0       121                0           16        12170
# 0       121                0           17        13266
# 0       121                0           17        13779
# 0       121                0           18        16008
#
#    neutral_minions_killed  total_minions_killed  kills  deaths  assists  \
# 0                     181                     6      7       2       10
# 0                     179                    16      6       0       13
# 0                     180                    23      9       2        7
# 0                     182                    18     13       2       11
# 0                     180                    20     13       7        7
#
#    first_blood  total_damage_dealt  total_damage_shielded  total_damage_taken  \
# 0         True              254406                      0               30676
# 0        False              256447                      0               24319
# 0        False              267159                      0               36601
# 0        False              268289                      0               36992
# 0        False              318618                      0               47874
#
#    total_time_cc_dealt  early_surrender  surrender  item0  item1  item2  \
# 0                  231            False      False   6701   3171   3142
# 0                  215            False      False   6701   3134   3142
# 0                  287            False      False   6701   3814   3142
# 0                  150            False      False   6701   3814   3142
# 0                  348            False      False   6701   3171   3142
#
#    item3  item4  item5  item6  summoner_1_id  summoner_2_id  wards_placed  \
# 0   3814   1036   1036   3364              4             11             2
# 0   2022   1001   1036   3364              4             11             3
# 0   3111   1036      0   3364              4             11             2
# 0   3158   6694      0   3364              4             11             1
# 0   3814   6694   3134   3364              4             11             1
#
#    wards_killed  vision_score  objectives_stolen  objectives_stolen_assists  \
# 0             0            15                  0                          0
# 0             1            25                  0                          0
# 0             1            13                  0                          0
# 0             4            20                  0                          0
# 0             2            22                  0                          0
#
#           defense            flex         offense primary_style  \
# 0  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 0  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 0  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 0  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 0  Health Scaling  Adaptive Force  Adaptive Force     Precision
#
#   secondary_style primary_keystone primary_perk_1   primary_perk_2  \
# 0       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 0       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 0       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 0       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 0       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
#
#     primary_perk_3 secondary_perk_1 secondary_perk_2
# 0  Treasure Hunter          Triumph    Coup de Grace
# 0  Treasure Hunter          Triumph    Coup de Grace
# 0  Treasure Hunter          Triumph    Coup de Grace
# 0  Treasure Hunter          Triumph    Coup de Grace
# 0  Treasure Hunter          Triumph    Coup de Grace

# %% [markdown]
# ### **7. Storing Data in SQL**

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from pangres import upsert
from sqlalchemy import create_engine, text

db_host=os.environ.get('db_host')
db_port=os.environ.get('db_port')
db_name=os.environ.get('db_name')
db_username=os.environ.get('db_username')
db_password=os.environ.get('db_password')


def create_db_connection_url(db_host=None, db_port=None, db_name=None, db_username=None, db_password=None):
    connection_url = f'postgresql+psycopg2://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}'
    return connection_url

conn = create_db_connection_url(db_host, db_port, db_name, db_username, db_password)

db_engine = create_engine(conn, pool_recycle=3600)

connection = db_engine.connect()

# %%
df['uuid'] = df['match_id'] + '_' + df['summoner_id']
df.set_index('uuid', inplace=True)

df
# Out:
#                                                            match_id  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  EUW1_7317675815
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  EUW1_7316614390
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  EUW1_7315801214
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  EUW1_7315747405
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  EUW1_7311182902
#
#                                                                                          participants  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  [9yECzY_qZRykY05W1qz37r4loWBQjA0gF3rNuEuqqHmtl...
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  [ane_rqP8NlA6dPk3xjdamKA91ZALfRyVekIxSmWI6YCbV...
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...
#
#                                                     game_creation  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  1740410317834
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  1740325731450
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  1740258651379
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  1740256517587
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  1739908043173
#
#                                                     game_duration  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           1703
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           1597
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           1830
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           1719
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           2410
#
#                                                     game_start_timestamp  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...         1740410350088
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...         1740325754586
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...         1740258775404
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...         1740256568697
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...         1739908071002
#
#                                                     game_end_timestamp  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       1740412053643
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       1740327352070
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       1740260605495
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       1740258288305
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       1739910481503
#
#                                                             patch  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  15.4.657.5386
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  15.4.657.5386
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  15.4.657.5386
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  15.4.657.5386
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  15.3.656.4086
#
#                                                         riot_id riot_tag  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  LordVoItage      EUW
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  LordVoItage      EUW
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  LordVoItage      EUW
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  LordVoItage      EUW
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  LordVoItage      EUW
#
#                                                                                         summoner_id  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
#
#                                                    summoner_name    win  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                 True
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                 True
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                 True
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                 True
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                False
#
#                                                     champ_id  champ_transform  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       121                0
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       121                0
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       121                0
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       121                0
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       121                0
#
#                                                     champ_level  gold_earned  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           16        12783
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           16        12170
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           17        13266
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           17        13779
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...           18        16008
#
#                                                     neutral_minions_killed  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                     181
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                     179
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                     180
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                     182
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                     180
#
#                                                     total_minions_killed  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                     6
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                    16
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                    23
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                    18
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                    20
#
#                                                     kills  deaths  assists  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      7       2       10
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      6       0       13
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      9       2        7
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     13       2       11
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     13       7        7
#
#                                                     first_blood  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...         True
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...        False
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...        False
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...        False
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...        False
#
#                                                     total_damage_dealt  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              254406
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              256447
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              267159
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              268289
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              318618
#
#                                                     total_damage_shielded  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                      0
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                      0
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                      0
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                      0
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                      0
#
#                                                     total_damage_taken  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...               30676
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...               24319
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...               36601
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...               36992
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...               47874
#
#                                                     total_time_cc_dealt  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  231
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  215
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  287
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  150
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  348
#
#                                                     early_surrender  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            False
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            False
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            False
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            False
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            False
#
#                                                     surrender  item0  item1  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      False   6701   3171
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      False   6701   3134
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      False   6701   3814
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      False   6701   3814
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      False   6701   3171
#
#                                                     item2  item3  item4  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   3142   3814   1036
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   3142   2022   1001
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   3142   3111   1036
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   3142   3158   6694
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   3142   3814   6694
#
#                                                     item5  item6  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   1036   3364
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   1036   3364
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      0   3364
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...      0   3364
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...   3134   3364
#
#                                                     summoner_1_id  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              4
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              4
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              4
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              4
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...              4
#
#                                                     summoner_2_id  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             11
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             11
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             11
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             11
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             11
#
#                                                     wards_placed  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             2
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             3
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             2
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             1
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             1
#
#                                                     wards_killed  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             0
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             1
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             1
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             4
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...             2
#
#                                                     vision_score  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            15
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            25
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            13
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            20
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...            22
#
#                                                     objectives_stolen  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  0
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  0
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  0
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  0
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                  0
#
#                                                     objectives_stolen_assists  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                          0
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                          0
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                          0
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                          0
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...                          0
#
#                                                            defense  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Health Scaling
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Health Scaling
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Health Scaling
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Health Scaling
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Health Scaling
#
#                                                               flex  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
#
#                                                            offense  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Adaptive Force
#
#                                                    primary_style  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Precision
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Precision
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Precision
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Precision
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Precision
#
#                                                    secondary_style  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       Precision
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       Precision
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       Precision
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       Precision
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...       Precision
#
#                                                    primary_keystone  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Dark Harvest
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Dark Harvest
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Dark Harvest
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Dark Harvest
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...     Dark Harvest
#
#                                                    primary_perk_1  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Sudden Impact
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Sudden Impact
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Sudden Impact
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Sudden Impact
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Sudden Impact
#
#                                                      primary_perk_2  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Grisly Mementos
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Grisly Mementos
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Grisly Mementos
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Grisly Mementos
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Grisly Mementos
#
#                                                      primary_perk_3  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Treasure Hunter
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Treasure Hunter
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Treasure Hunter
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Treasure Hunter
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...  Treasure Hunter
#
#                                                    secondary_perk_1  \
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...          Triumph
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...          Triumph
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...          Triumph
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...          Triumph
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...          Triumph
#
#                                                    secondary_perk_2
# uuid
# EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...    Coup de Grace
# EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...    Coup de Grace
# EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...    Coup de Grace
# EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...    Coup de Grace
# EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb...    Coup de Grace

# %%
upsert(con=connection, df=df, schema='soloq', table_name='regional_player_matches', create_table=True, create_schema=True, if_row_exists='update')

# %%
connection.commit()

# %%
def get_soloq_games(side=None, db_engine=None):
    with db_engine.connect() as connection:
        df = pd.read_sql(text(f"""SELECT 
                                    * 
                                  FROM 
                                    soloq.regional_player_matches
                                  WHERE
                                    side = '{side}"""), connection)
    return df

# %%
df
# Out:
#                                                 uuid         match_id  \
# 0  EUW1_7317675815_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsS...  EUW1_7317675815
# 1  EUW1_7316614390_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsS...  EUW1_7316614390
# 2  EUW1_7315801214_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsS...  EUW1_7315801214
# 3  EUW1_7315747405_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsS...  EUW1_7315747405
# 4  EUW1_7311182902_N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsS...  EUW1_7311182902
#
#                                         participants  game_creation  \
# 0  [9yECzY_qZRykY05W1qz37r4loWBQjA0gF3rNuEuqqHmtl...  1740410317834
# 1  [ane_rqP8NlA6dPk3xjdamKA91ZALfRyVekIxSmWI6YCbV...  1740325731450
# 2  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...  1740258651379
# 3  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...  1740256517587
# 4  [H_JK6bXTiLE3NiMXecRMaOIE5raLhzWkJ_manTPFxHhoM...  1739908043173
#
#    game_duration  game_start_timestamp  game_end_timestamp          patch  \
# 0           1703         1740410350088       1740412053643  15.4.657.5386
# 1           1597         1740325754586       1740327352070  15.4.657.5386
# 2           1830         1740258775404       1740260605495  15.4.657.5386
# 3           1719         1740256568697       1740258288305  15.4.657.5386
# 4           2410         1739908071002       1739910481503  15.3.656.4086
#
#        riot_id riot_tag                                      summoner_id  \
# 0  LordVoItage      EUW  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# 1  LordVoItage      EUW  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# 2  LordVoItage      EUW  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# 3  LordVoItage      EUW  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
# 4  LordVoItage      EUW  N7UjrBLG_BZC-wQf2Nw3QI-ACcUDsSb69YfXsmT48LiztMg
#
#   summoner_name    win  champ_id  champ_transform  champ_level  gold_earned  \
# 0                 True       121                0           16        12783
# 1                 True       121                0           16        12170
# 2                 True       121                0           17        13266
# 3                 True       121                0           17        13779
# 4                False       121                0           18        16008
#
#    neutral_minions_killed  total_minions_killed  kills  deaths  assists  \
# 0                     181                     6      7       2       10
# 1                     179                    16      6       0       13
# 2                     180                    23      9       2        7
# 3                     182                    18     13       2       11
# 4                     180                    20     13       7        7
#
#    first_blood  total_damage_dealt  total_damage_shielded  total_damage_taken  \
# 0         True              254406                      0               30676
# 1        False              256447                      0               24319
# 2        False              267159                      0               36601
# 3        False              268289                      0               36992
# 4        False              318618                      0               47874
#
#    total_time_cc_dealt  early_surrender  surrender  item0  item1  item2  \
# 0                  231            False      False   6701   3171   3142
# 1                  215            False      False   6701   3134   3142
# 2                  287            False      False   6701   3814   3142
# 3                  150            False      False   6701   3814   3142
# 4                  348            False      False   6701   3171   3142
#
#    item3  item4  item5  item6  summoner_1_id  summoner_2_id  wards_placed  \
# 0   3814   1036   1036   3364              4             11             2
# 1   2022   1001   1036   3364              4             11             3
# 2   3111   1036      0   3364              4             11             2
# 3   3158   6694      0   3364              4             11             1
# 4   3814   6694   3134   3364              4             11             1
#
#    wards_killed  vision_score  objectives_stolen  objectives_stolen_assists  \
# 0             0            15                  0                          0
# 1             1            25                  0                          0
# 2             1            13                  0                          0
# 3             4            20                  0                          0
# 4             2            22                  0                          0
#
#           defense            flex         offense primary_style  \
# 0  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 1  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 2  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 3  Health Scaling  Adaptive Force  Adaptive Force     Precision
# 4  Health Scaling  Adaptive Force  Adaptive Force     Precision
#
#   secondary_style primary_keystone primary_perk_1   primary_perk_2  \
# 0       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 1       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 2       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 3       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
# 4       Precision     Dark Harvest  Sudden Impact  Grisly Mementos
#
#     primary_perk_3 secondary_perk_1 secondary_perk_2
# 0  Treasure Hunter          Triumph    Coup de Grace
# 1  Treasure Hunter          Triumph    Coup de Grace
# 2  Treasure Hunter          Triumph    Coup de Grace
# 3  Treasure Hunter          Triumph    Coup de Grace
# 4  Treasure Hunter          Triumph    Coup de Grace
